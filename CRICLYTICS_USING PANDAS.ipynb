# %% [markdown]
# <h3><center>
#
# **NAME     :** *R AKHILANDESHWARI*
#
# **REG NO   :** 2048046
# *italicized text*
#
# **TOPIC    :** *CRICLYTICS USING PANDAS*</h3></center>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2><center><b>PROBLEM STATEMENT</b></center></h2>
#
# <h6>After the death of Mr. Jagmohan Dalmia BCCI is worried about the performance
# of Indian team in the worldcup as they didn’t qualify for the finals in the last season.
# They believe that legendary cricketer, Prince of Kolkata, Mr. Sourav Ganguly (Dada)
# can do some magic to bring the worldcup back in India. BCCI appointed him as the
# 35th Chairman. Dada feels that there will be a cut throat competition in coming
# worldcup. He wants you, the future data analysts to help him perform criclytics by
# analyzing the data and come up with patterns which will help us in bring the cup to
# home this time. I am sure you will do the needful. ALL THE BEST!</h6>

# %%
#Reading the Wordcup Players Data
pl=pd.read_csv('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/WC_players.csv')

#Reading the ODI_Match_Totals Data
omt=pd.read_csv('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/ODI_Match_Totals.csv')

#Reading the ODI_Match_Results Data
omr=pd.read_csv('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/ODI_Match_Results.csv')

#Reading the Ground_Averages Data
ga=pd.read_csv('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/Ground_Averages.csv')

#Reading the Bowlers Data
bow=pd.read_excel('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/Bowler_data.xlsx')

#Reading the Batsman Data
bat=pd.read_csv('/content/drive/My Drive/PYTHON EVALUATION CODES/2019_worldcup_archive/Batsman_Data.csv')

# %% [markdown]
# <h2><center><b>
# ANALYSING THE WC_players.csv
# </h2></center></b>

# %%
pl.columns
# Out:
# Index(['Player', 'ID', 'Country'], dtype='object')

# %%
pl_Indians=pl[pl['Country']=='India']
print("The shape of the data is",pl_Indians.shape)
pl_Indians
# Out:
# The shape of the data is (15, 3)
#                Player      ID Country
# 61    Virat Kohli (c)  253802   India
# 62  Rohit Sharma (vc)   34102   India
# 63     Shikhar Dhawan   28235   India
# 64        K. L. Rahul  422108   India
# 65      Vijay Shankar  477021   India
# 66      MS Dhoni (wk)   28081   India
# 67       Kedar Jadhav  290716   India
# 68     Dinesh Karthik   30045   India
# 69   Yuzvendra Chahal  430246   India
# 70      Kuldeep Yadav  559235   India
# 71  Bhuvneshwar Kumar  326016   India
# 72     Jasprit Bumrah  625383   India
# 73      Hardik Pandya  625371   India
# 74    Ravindra Jadeja  234675   India
# 75     Mohammed Shami  481896   India

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>As the WC_players.csv contains only the Player details.We got to know who all are the Indian Players who played for the team.There are 15 Indian players in the given data.</i>

# %% [markdown]
# <h2><center><b>
# ANALYSING THE Ground_Averages.csv
# </h2></center></b>

# %%
#To know the existing columns
ga.columns
# Out:
# Index(['Ground', 'Span', 'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts', 'Balls',
#        'Ave', 'RPO'],
#       dtype='object')

# %%
#To view the data
ga
# Out:
#                                                 Ground       Span  ...    Ave   RPO
# 0                        Eden Gardens, Kolkata - India  2013-2017  ...  30.01  5.64
# 1                      Feroz Shah Kotla, Delhi - India  2013-2019  ...  23.85  4.60
# 2                 Melbourne Cricket Ground - Australia  2013-2019  ...  35.28  5.41
# 3    Saurashtra Cricket Association Stadium, Rajkot...  2013-2015  ...  44.73  5.81
# 4                            Adelaide Oval - Australia  2013-2019  ...  30.97  5.16
# ..                                                 ...        ...  ...    ...   ...
# 101  Greenfield International Stadium, Thiruvananth...  2018-2018  ...  19.00  4.47
# 102  Sylhet International Cricket Stadium - Bangladesh  2018-2018  ...  36.36  4.51
# 103  Rajiv Gandhi International Cricket Stadium, De...  2019-2019  ...  27.82  4.43
# 104       Wanderers Cricket Ground, Windhoek - Namibia  2019-2019  ...  18.05  3.88
# ...

# %%
ga.plot(kind='scatter',x='Won',y='Runs')
plt.title('Won Vs Runs (To find Relation between them)')
plt.show()

# %%
#The grounds on which the team can perform well. The list is in the descending order. To understand the pitch of the ground
ga_ground=ga.sort_values(['Won','Runs'],ascending=False)
print("The analyse the ground pitch\n")
ga_ground
# Out:
# The analyse the ground pitch
#                                                 Ground       Span  ...    Ave   RPO
# 46                       Harare Sports Club - Zimbabwe  2013-2019  ...  28.30  4.76
# 53   Shere Bangla National Stadium, Mirpur, Dhaka -...  2013-2018  ...  27.58  4.99
# 21                    Sharjah Cricket Stadium - U.A.E.  2013-2019  ...  27.45  4.94
# 30             Queens Sports Club, Bulawayo - Zimbabwe  2013-2018  ...  29.55  4.90
# 58            Sheikh Zayed Stadium, Abu Dhabi - U.A.E.  2013-2019  ...  28.14  4.76
# ..                                                 ...        ...  ...    ...   ...
# 102  Sylhet International Cricket Stadium - Bangladesh  2018-2018  ...  36.36  4.51
# 47    Maple Leaf North-West Ground, King City - Canada  2013-2013  ...  15.54  4.67
# 105                    Affies Park, Windhoek - Namibia  2019-2019  ...  21.93  4.29
# 104       Wanderers Cricket Ground, Windhoek - Namibia  2019-2019  ...  18.05  3.88
# ...

# %%
#To know the Run per over the batsman can score
ga_RPO=ga.sort_values(['RPO'],ascending=True)
print("To plan the Batsman strategy\n")
ga_RPO
# Out:
# To plan the Batsman strategy
#                                                 Ground       Span  ...     Ave   RPO
# 104       Wanderers Cricket Ground, Windhoek - Namibia  2019-2019  ...   18.05  3.88
# 105                    Affies Park, Windhoek - Namibia  2019-2019  ...   21.93  4.29
# 97                   Bulawayo Athletic Club - Zimbabwe  2018-2018  ...   24.56  4.43
# 103  Rajiv Gandhi International Cricket Stadium, De...  2019-2019  ...   27.82  4.43
# 72       Kinrara Academy Oval, Kuala Lumpur - Malaysia  2014-2018  ...   24.59  4.45
# ..                                                 ...        ...  ...     ...   ...
# 76                   Barabati Stadium, Cuttack - India  2014-2017  ...   44.96  6.88
# 56            M.Chinnaswamy Stadium, Bengaluru - India  2013-2017  ...   46.75  6.94
# 99         Barsapara Cricket Stadium, Guwahati - India  2018-2018  ...   64.80  7.03
# 52              Sawai Mansingh Stadium, Jaipur - India  2013-2013  ...  120.16  7.71
# ...

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>I have sorted the ground data in the descending order of the Matches won and the runs scored. So, we can plan the game strategy based on the ground selected for the match and its pitch. I have sorted the RPO in aascending order to know the minimum runs can a batsman can score in a ground</i>

# %% [markdown]
# <h2><center><b>
# ANALYSING THE ODI_Match_Totals.csv
# </h2></center></b>

# %%
#To know the existing columns 
omt.columns
# Out:
# Index(['Unnamed: 0', 'Score', 'Overs', 'RPO', 'Target', 'Inns', 'Result',
#        'Opposition', 'Ground', 'Start Date', 'Match_ID', 'Country',
#        'Country_ID'],
#       dtype='object')

# %%
#To view the Data 
omt
# Out:
#       Unnamed: 0  Score  Overs  ...    Match_ID      Country  Country_ID
# 0            412    250   48.3  ...  ODI # 3315     Pakistan           7
# 1            680    165   48.0  ...  ODI # 3315        India           6
# 2            413    157   48.5  ...  ODI # 3316     Pakistan           7
# 3            681    167   43.4  ...  ODI # 3316        India           6
# 4            117    198   40.0  ...  ODI # 3317     SriLanka           8
# ...          ...    ...    ...  ...         ...          ...         ...
# 1291         549  340/7   50.0  ...  ODI # 4138     Pakistan           7
# 1292         979  341/7   49.3  ...  ODI # 4138      England           1
# 1293        1296  120/8   33.0  ...  ODI # 4139  Afghanistan          40
# 1294         550  193/6   31.5  ...  ODI # 4140     Pakistan           7
# 1295         980  351/9   50.0  ...  ODI # 4140      England           1
#
# [1296 rows x 13 columns]

# %%
#Extracting the Indian Matches 
omt_Indians=omt[omt['Country']=='India']
omt_Indians
# Out:
#       Unnamed: 0  Score  Overs  ...    Match_ID  Country  Country_ID
# 1            680    165   48.0  ...  ODI # 3315    India           6
# 3            681    167   43.4  ...  ODI # 3316    India           6
# 6            682  316/9   50.0  ...  ODI # 3318    India           6
# 10           683  285/6   50.0  ...  ODI # 3320    India           6
# 14           684  157/3   28.1  ...  ODI # 3322    India           6
# ...          ...    ...    ...  ...         ...      ...         ...
# 1239         831  240/4   48.2  ...  ODI # 4102    India           6
# 1246         832    250   48.2  ...  ODI # 4106    India           6
# 1251         833    281   48.2  ...  ODI # 4109    India           6
# 1254         834  358/9   50.0  ...  ODI # 4111    India           6
# 1258         835    237   50.0  ...  ODI # 4113    India           6
#
# [156 rows x 13 columns]

# %%
#The matches which India have Won
omt_Indians_Won=omt_Indians[omt_Indians['Result']=='won']
omt_Indians_Won
# Out:
#       Unnamed: 0  Score  Overs  ...    Match_ID  Country  Country_ID
# 3            681    167   43.4  ...  ODI # 3316    India           6
# 10           683  285/6   50.0  ...  ODI # 3320    India           6
# 14           684  157/3   28.1  ...  ODI # 3322    India           6
# 24           685  258/5   47.3  ...  ODI # 3327    India           6
# 81           687  331/7   50.0  ...  ODI # 3363    India           6
# ...          ...    ...    ...  ...         ...      ...         ...
# 1212         827  324/4   50.0  ...  ODI # 4085    India           6
# 1216         828  245/3   43.0  ...  ODI # 4088    India           6
# 1222         830    252   49.5  ...  ODI # 4092    India           6
# 1239         831  240/4   48.2  ...  ODI # 4102    India           6
# 1246         832    250   48.2  ...  ODI # 4106    India           6
#
# [99 rows x 13 columns]

# %% [markdown]
# <i><center>Therefore, Out of 156 matches India have won 99 matches.</i></center>

# %%
#filling the null values i the Targe column using the mean()
#omt_Indians_Won["Target"].fillna(omt_Indians_Won["Target"].mean(),inplace=True)   

#To find the avergae runs that should scored 
print("The average score that should be aimed at is\t:",omt_Indians_Won["Target"].mean())
# Out:
# The average score that should be aimed at is	: 221.9322033898305

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>Firstly, I have separeted the Indian matches from the whole list. Then, I have calculated no.of matches that India have won. Later, I have caluculate the average score that India have to target while playing the matches is 222 Runs.
# </i>

# %% [markdown]
# <h2><center><b>
# ANALYSING THE ODI_Match_Results.csv
# </h2></center></b>

# %%
#To know the existing columns 
omr.columns
# Out:
# Index(['Unnamed: 0', 'Result', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition',
#        'Ground', 'Start Date', 'Match_ID', 'Country', 'Country_ID'],
#       dtype='object')

# %%
#To view the data
omr.head(5)
# Out:
#    Unnamed: 0 Result    Margin  ...    Match_ID   Country Country_ID
# 0         418    won   85 runs  ...  ODI # 3315  Pakistan          7
# 1         692   lost   85 runs  ...  ODI # 3315     India          6
# 2         419   lost   10 runs  ...  ODI # 3316  Pakistan          7
# 3         693    won   10 runs  ...  ODI # 3316     India          6
# 4         121   lost  107 runs  ...  ODI # 3317  SriLanka          8
#
# [5 rows x 12 columns]

# %%
#Extracting the Indian Matches 
omr_Indians=omr[omr['Country']=='India']
omr_Indians
# Out:
#       Unnamed: 0 Result     Margin  ...    Match_ID Country Country_ID
# 1            692   lost    85 runs  ...  ODI # 3315   India          6
# 3            693    won    10 runs  ...  ODI # 3316   India          6
# 6            694   lost     9 runs  ...  ODI # 3318   India          6
# 10           695    won   127 runs  ...  ODI # 3320   India          6
# 14           696    won  7 wickets  ...  ODI # 3322   India          6
# ...          ...    ...        ...  ...         ...     ...        ...
# 1262         847    won  6 wickets  ...  ODI # 4102   India          6
# 1269         848    won     8 runs  ...  ODI # 4106   India          6
# 1274         849   lost    32 runs  ...  ODI # 4109   India          6
# 1277         850   lost  4 wickets  ...  ODI # 4111   India          6
# 1281         851   lost    35 runs  ...  ODI # 4113   India          6
#
# [160 rows x 12 columns]

# %%
#The matches which India have Won
omr_Indians_Won=omr_Indians[omr_Indians['Result']=='won']
omr_Indians_Won
# Out:
#       Unnamed: 0 Result     Margin  ...    Match_ID Country Country_ID
# 3            693    won    10 runs  ...  ODI # 3316   India          6
# 10           695    won   127 runs  ...  ODI # 3320   India          6
# 14           696    won  7 wickets  ...  ODI # 3322   India          6
# 24           697    won  5 wickets  ...  ODI # 3327   India          6
# 82           699    won    26 runs  ...  ODI # 3363   India          6
# ...          ...    ...        ...  ...         ...     ...        ...
# 1235         843    won    90 runs  ...  ODI # 4085   India          6
# 1239         844    won  7 wickets  ...  ODI # 4088   India          6
# 1245         846    won    35 runs  ...  ODI # 4092   India          6
# 1262         847    won  6 wickets  ...  ODI # 4102   India          6
# 1269         848    won     8 runs  ...  ODI # 4106   India          6
#
# [99 rows x 12 columns]

# %% [markdown]
# <i><center>Therefore, Out of 160 matches India have won 99 matches.</i></center>

# %%
Toss_Winning=omr_Indians_Won[omr_Indians_Won['Toss']=='won']
print("No.of Matches won after the toss is won is \t:",Toss_Winning.shape)
# Out:
# No.of Matches won after the toss is won is 	: (51, 12)

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>India have won the toss in 51 matches out off 99 winning matches. Therefore, the saying which states that, Winning toss is equallent to winning match holds good in Indian Team.</i>

# %% [markdown]
# <h2><center><b>
# ANALYSING THE Bowler_data.csv
# </h2></center></b>

# %%
#To know the columns of the data
bow.columns
# Out:
# Index(['Unnamed: 0', 'Overs', 'Mdns', 'Runs', 'Wkts', 'Econ', 'Ave', 'SR',
#        'Opposition', 'Ground', 'Start Date', 'Match_ID', 'Bowler',
#        'Player_ID'],
#       dtype='object')

# %%
#To separate separate the Indian players from the data
#While analysing the WC_Players.csv we have extracted the Indian Players list to variable pl_Indians
# Bowler Data of Indian Players
cricket_bowler={}
for i in pl_Indians['ID']:
    for j in bow['Player_ID']:
        if i==j:
            a=bow.loc[bow['Player_ID'] == i]
            b=pl_Indians.loc[pl_Indians['ID']==j]
            Name=b['Player'].sum()
            mdns=a['Mdns'].sum()
            runs=a['Runs'].sum()
            wkts=a['Wkts'].sum()
            eco=a['Econ'].mean()
            sr=a['SR'].mean()
            cricket_bowler[i]=[Name,mdns,runs,wkts,eco,sr]
cricket_bowler=pd.DataFrame.from_dict(cricket_bowler).T
cricket_bowler=cricket_bowler.rename(columns={0:"Name",1:"MDNS",2:"Runs",3:"WKTS",4:"ECO",5:"SR"})

# Sorting the batsman data according to their Economy rate
cricket_bowler_LowEconomy=cricket_bowler.sort_values(['ECO'],ascending=True)
cricket_bowler_MaxWicket=cricket_bowler.sort_values(['WKTS'],ascending=False)

# %%
#The top 5 bowlers with low economy rate

Best_Bowler_A=cricket_bowler_LowEconomy.head(5)
Best_Bowler_A
# Out:
#                      Name MDNS  Runs WKTS      ECO       SR
# 625383     Jasprit Bumrah   26  1883   85  4.44592  29.0024
# 559235      Kuldeep Yadav   10  1892   87  4.91619  27.6886
# 326016  Bhuvneshwar Kumar   65  4209  118   4.9999  36.5029
# 234675    Ravindra Jadeja   49  6245  174  5.02061    37.75
# 430246   Yuzvendra Chahal   12  1772   72      5.1  32.8636

# %%
#The Top 5 bowlers who take maximum wickets

Best_Bowler_B=cricket_bowler_MaxWicket.head(5)
Best_Bowler_B
# Out:
#                      Name MDNS  Runs WKTS      ECO       SR
# 234675    Ravindra Jadeja   49  6245  174  5.02061    37.75
# 326016  Bhuvneshwar Kumar   65  4209  118   4.9999  36.5029
# 481896     Mohammed Shami   33  2951  113   5.4721  30.9906
# 559235      Kuldeep Yadav   10  1892   87  4.91619  27.6886
# 625383     Jasprit Bumrah   26  1883   85  4.44592  29.0024

# %%
#The Best Bowlers are 
Best_Bowler_A_Names=cricket_bowler_LowEconomy['Name'].head(5)
BBAL=set(Best_Bowler_A_Names)
Best_Bowler_B_Names=cricket_bowler_MaxWicket['Name'].head(5)
BBBL=set(Best_Bowler_B_Names)
Best_Bowlers=BBAL.union(BBBL)
Indian_Best_Bowlers=list(Best_Bowlers)
Indian_Best_Bowlers
# Out:
# ['Ravindra Jadeja',
#  'Bhuvneshwar Kumar',
#  'Jasprit Bumrah',
#  'Mohammed Shami',
#  'Yuzvendra Chahal',
#  'Kuldeep Yadav']

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>The best Bowlers with less economy rate and maximum wicket taking capability are as follows.
#  </i>
#
# 1. Jasprit Bumrah
# 2. Kuldeep Yadav
# 3. Bhuvaneshwar Kumar
# 4. Ravindra Jadeja
# 5. Yuzvendra Chahal
# 6. Mohammed Shami

# %% [markdown]
# <h2><center><b>
# ANALYSING THE Batsman_Data.csv
# </h2></center></b>

# %%
#To know the columns of the data
bat.columns
# Out:
# Index(['Unnamed: 0', 'Bat1', 'Runs', 'BF', 'SR', '4s', '6s', 'Opposition',
#        'Ground', 'Start Date', 'Match_ID', 'Batsman', 'Player_ID'],
#       dtype='object')

# %%
#To separate separate the Indian players from the data
#While analysing the WC_Players.csv we have extracted the Indian Players list to variable pl_Indians
# Batsman Data of Indian Playersbat.columns
cricket_batsman={}
for i in pl_Indians['ID']:
    for j in bat['Player_ID']:
        if i==j:
            a=bat.loc[bat['Player_ID'] == i]
            b=pl_Indians.loc[pl_Indians['ID']==j]
            Name=b['Player'].sum()
            run=a['Runs'].mean()
            fours=a['4s'].sum()
            sixs=a['6s'].sum()
            sr=a['SR'].mean()
            cricket_batsman[i]=[Name,run,fours,sixs,sr]
cricket_batsman=pd.DataFrame.from_dict(cricket_batsman).T 
cricket_batsman=cricket_batsman.rename(columns={0:"Name",1:"Runs",2:"4s",3:"6s",4:"SR"})

# Sorting the batsman data according to the number of 6s and their strike rate
cricket_batsman=cricket_batsman.sort_values(['6s','SR'],ascending=False)

# Display the selected batsman
cricket_batsman
# Out:
#                      Name     Runs    4s   6s       SR
# 28081       MS Dhoni (wk)  36.3322   806  224  87.6982
# 34102   Rohit Sharma (vc)    40.05   699  218  69.2796
# 253802    Virat Kohli (c)  49.5114  1019  116  79.8831
# 28235      Shikhar Dhawan  42.1654   666   67  83.8055
# 234675    Ravindra Jadeja  20.1485   155   37  86.1606
# 625371      Hardik Pandya  25.2069    48   36   113.73
# 290716       Kedar Jadhav    29.35   121   20  98.7587
# 30045      Dinesh Karthik  22.5714   174   15  69.5069
# 326016  Bhuvneshwar Kumar  10.6735    44    8  69.7574
# 481896     Mohammed Shami  4.51724    10    6  88.7976
# 422108        K. L. Rahul  26.3846    26    5  72.0885
# 477021      Vijay Shankar       33    14    4  107.736
# 625383     Jasprit Bumrah      1.8     2    1  89.1967
# 559235      Kuldeep Yadav  5.55556     8    0   61.995
# 430246   Yuzvendra Chahal  4.85714     5    0  36.9486

# %%
#Top 6 Batsman with good strike rate
Best_Batsman=cricket_batsman.head(10)
Best_Batsman=cricket_batsman['Name'].head(10)
Indian_Best_Batsman=list(Best_Batsman)
Indian_Best_Batsman
# Out:
# ['MS Dhoni (wk)',
#  'Rohit Sharma (vc)',
#  'Virat Kohli (c)',
#  'Shikhar Dhawan',
#  'Ravindra Jadeja',
#  'Hardik Pandya',
#  'Kedar Jadhav',
#  'Dinesh Karthik',
#  'Bhuvneshwar Kumar',
#  'Mohammed Shami']

# %% [markdown]
# <h3><b>INFERENCE:</h3></b><br>
# <i>The best Batsman with good strike rate are:
#  </i>
#
# 1. MS Dhoni (wk)
#
# 2. Rohit Sharma (vc)
#
# 3. Virat Kohli (c)
#
# 4. Shikhar Dhawan
#
# 5. Ravindra Jadeja
#
# 6. Hardik Pandya
#
# 7. Kedar Jadhav
#
# 8. Dinesh Karthik
#
# 9. Bhuvneshwar Kumar
#
# 10. Mohammed Shami

# %% [markdown]
# <center><b><h1><i><u>THE WORLD CUP 2023 INDIAN CRICKET TEAM </u></i></h1></b></center><br>
#
# 1. Virat Kohli (c)
#
# 2. Rohit Sharma (vc)
#
# 3. Shikhar Dhawan
#
# 4. Ravindra Jadeja
#
# 5. Hardik Pandya
#
# 6. Kedar Jadhav
#
# 7. Dinesh Karthik (wk)
#
# 8. Bhuvneshwar Kumar
#
# 9. Mohammed Shami
#
# 10. Jasprit Bumrah
#
# 11. Kuldeep Yadav
#
# 12. Yuzvendra Chahal
